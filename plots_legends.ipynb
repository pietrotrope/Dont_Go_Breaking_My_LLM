# %%
import matplotlib.pyplot as plt 
import pylab as pl
import numpy as np
import matplotlib.colors as colors

def truncate_colormap(cmap, minval=0.0, maxval=1.0, n=100):
    new_cmap = colors.LinearSegmentedColormap.from_list(
        'trunc({n},{a:.2f},{b:.2f})'.format(n=cmap.name, a=minval, b=maxval),
        cmap(np.linspace(minval, maxval, n)))
    return new_cmap

cmap = plt.get_cmap('CMRmap_r')

a = np.array([[0,0.3]])
pl.figure(figsize=(10, 1))
img = pl.imshow(a, cmap=truncate_colormap(cmap, 0.2, 0.9))
pl.gca().set_visible(False)
cax = pl.axes([0.05, 0.3, 0.9, 0.6])
pl.tight_layout()
pl.colorbar(orientation="horizontal", cax=cax)
pl.savefig("./results/plots/legends/legend_layer_importance.pdf", transparent=True)
#pl.savefig("colorbar.pdf")
# Out:
# anonymized path: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   pl.tight_layout()

# %%
import matplotlib.pyplot as plt 
width = 10
height = 4

cmap = plt.get_cmap("tab10")

colors={"5":cmap(0),
        "10":cmap(1),
        "20":cmap(2)}

fig = plt.figure()

ax = fig.add_subplot(111)
ax.set_axis_off()

plt.figure(figsize=(width, height))
    

labels = list(colors.keys())
handles = [plt.Rectangle((0,0),0,0, color=colors[label]) for label in labels]


handles = [patches.Rectangle((0,0), 1, 1, fill=False, edgecolor='none',
                                 visible=False)] + handles
labels = ["# top features:"] + labels


fig.legend(handles, labels, loc="center", bbox_to_anchor=(0.5, 0.5), prop={"size":110}, labelspacing=2, ncol=5)

fig.savefig('./results/plots/legends/legend_overlap_at_k.pdf', dpi=400, transparent=True, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt 
import pylab as pl
import numpy as np
import matplotlib.colors as colors

def truncate_colormap(cmap, minval=0.0, maxval=1.0, n=100):
    new_cmap = colors.LinearSegmentedColormap.from_list(
        'trunc({n},{a:.2f},{b:.2f})'.format(n=cmap.name, a=minval, b=maxval),
        cmap(np.linspace(minval, maxval, n)))
    return new_cmap

cmap = plt.get_cmap('coolwarm')

a = np.array([[0,1]])
pl.figure(figsize=(10, 1))
img = pl.imshow(a, cmap=cmap)
pl.gca().set_visible(False)
cax = pl.axes([0.05, 0.35, 0.9, 0.5])
pl.tight_layout()
pl.colorbar(orientation="horizontal", cax=cax)
pl.savefig("./results/plots/legends/legend_overlap_heatmaps.pdf", transparent=True)
#pl.savefig("colorbar.pdf")
# Out:
# anonymized path: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   pl.tight_layout()

# %%
import matplotlib.pyplot as plt 
import matplotlib.lines as mlines
width = 10
height = 3

prop_cycle = plt.rcParams['axes.prop_cycle']
#colors_l = prop_cycle.by_key()['color']

colors_l =["#0081FB","#FFA500"]

fig = plt.figure()

ax = fig.add_subplot(111)
ax.set_axis_off()

plt.figure(figsize=(width, height))
    

blue = mlines.Line2D([], [], color=colors_l[0], marker='s', linestyle='None',
                                    markersize=100)
orange = mlines.Line2D([], [], color=colors_l[1], marker='s', linestyle='None',
                        markersize=100)

dotted = mlines.Line2D([], [], color='black', linestyle='--',
                        markersize=100,linewidth=10)

not_dotted = mlines.Line2D([], [], color='black', linestyle='-',
                        markersize=100,linewidth=10)

#plt.legend(handles=)

fig.legend([blue, orange, dotted, not_dotted], ['Llama-2', 'Mistral', 'Unpruned models', 'Pruned models'], loc="center", bbox_to_anchor=(0.5, 0.5), prop={"size":110}, labelspacing=2, ncol=4)

fig.savefig('./results/plots/legends/legend_effectiveness.pdf', dpi=400, transparent=True, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt 
import matplotlib.patches as patches
width = 10
height = 3

colors = {
        "10%":"#fc7703",
        "20%":"#fc9003",
        "30%":"#fca903",
        "40%":"#fcc203",
        "50%":"#fcdb03"
}  

prop_cycle = plt.rcParams['axes.prop_cycle']
colors_l = prop_cycle.by_key()['color']

fig = plt.figure()

ax = fig.add_subplot(111)
ax.set_axis_off()


plt.figure(figsize=(width, height))
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),0,0, color=colors[label]) for label in labels]

handles = [patches.Rectangle((0,0), 1, 1, fill=False, edgecolor='none',
                                 visible=False)] + handles
labels = ["% tokens, sufficiency:              "] + labels # 22

fig.legend(handles, labels, loc="center", bbox_to_anchor=(0.5, 0.5), prop={"size":110}, labelspacing=0.5, ncol=8)

fig.savefig('./results/plots/legends/partial_suff.pdf', dpi=400, transparent=True, bbox_inches='tight')


              
colors = {
        "10%":"#033dfc",
        "20%":"#035efc",
        "30%":"#0394fc",
        "40%":"#03bafc",
        "50%":"#03cafc",
        }

prop_cycle = plt.rcParams['axes.prop_cycle']
colors_l = prop_cycle.by_key()['color']

fig = plt.figure()

ax = fig.add_subplot(111)
ax.set_axis_off()

plt.figure(figsize=(width, height))
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),0,0, color=colors[label]) for label in labels]

handles = [patches.Rectangle((0,0), 1, 1, fill=False, edgecolor='none',
                                 visible=False)] + handles
labels = ["% tokens, comprehensiveness:"] + labels # 27

fig.legend(handles, labels, loc="center", bbox_to_anchor=(0.5, 0.5), prop={"size":110}, labelspacing=0.5, ncol=8)

fig.savefig('./results/plots/legends/partial_comp.pdf', dpi=400, transparent=True, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt 
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
width = 10
height = 3

prop_cycle = plt.rcParams['axes.prop_cycle']
colors_l = prop_cycle.by_key()['color']

fig = plt.figure()

ax = fig.add_subplot(111)
ax.set_axis_off()

plt.figure(figsize=(width, height))
    


h_suf = mpatches.Patch(color="#fc5e03")
h_comp = mpatches.Patch(color="#030ffc")
h_acc = mpatches.Patch(color="black")

h_pruned = Line2D([0,1],[0,1],linestyle='-', color='black', linewidth=10)
h_unpruned = Line2D([0,1],[0,1],linestyle='--', color='black', linewidth=10)


fig.legend([h_comp, h_suf, h_acc, h_pruned, h_unpruned], ["Comprehensiveness", 'Sufficiency', 'Accuracy', 'Pruned', 'Unpruned'], loc="center", bbox_to_anchor=(0.5, 0.5), prop={"size":110}, labelspacing=2, ncol=5)

fig.savefig('./results/plots/legends/legend_comp_suff.pdf', dpi=400, transparent=True, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt 
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
width = 10
height = 3

prop_cycle = plt.rcParams['axes.prop_cycle']
colors_l = prop_cycle.by_key()['color']

fig = plt.figure()

ax = fig.add_subplot(111)
ax.set_axis_off()

plt.figure(figsize=(width, height))
    


h_suf = mpatches.Patch(color="#fc5e03")
h_comp = mpatches.Patch(color="#030ffc")
h_acc = mpatches.Patch(color="black")

h_pruned = Line2D([0,1],[0,1],linestyle='-', color='black', linewidth=10)
h_unpruned = Line2D([0,1],[0,1],linestyle='--', color='black', linewidth=10)


fig.legend([h_comp, h_suf, h_acc], ["Comprehensiveness", 'Sufficiency', 'Accuracy'], loc="center", bbox_to_anchor=(0.5, 0.5), prop={"size":110}, labelspacing=2, ncol=5)

fig.savefig('./results/plots/legends/legend_comp_suff_delta.pdf', dpi=400, transparent=True, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt 
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
width = 10
height = 3

prop_cycle = plt.rcParams['axes.prop_cycle']
colors_l = prop_cycle.by_key()['color']

fig = plt.figure()

ax = fig.add_subplot(111)
ax.set_axis_off()

plt.figure(figsize=(width, height))
    


h_comp = mpatches.Patch(color="red")
h_acc = mpatches.Patch(color="black")

h_pruned = Line2D([0,1],[0,1],linestyle='-', color='black', linewidth=10)
h_unpruned = Line2D([0,1],[0,1],linestyle='--', color='black', linewidth=10)


fig.legend([h_comp, h_acc, h_pruned, h_unpruned], ["Confidence", 'Accuracy', 'Pruned', 'Unpruned'], loc="center", bbox_to_anchor=(0.5, 0.5), prop={"size":110}, labelspacing=2, ncol=5)

fig.savefig('./results/plots/legends/legend_avg_confidence.pdf', dpi=400, transparent=True, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt 
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
width = 10
height = 3

prop_cycle = plt.rcParams['axes.prop_cycle']
colors_l = prop_cycle.by_key()['color']

fig = plt.figure()

ax = fig.add_subplot(111)
ax.set_axis_off()

plt.figure(figsize=(width, height))
    


h_comp = mpatches.Patch(color="darkgreen")
h_acc = mpatches.Patch(color="black")


# Δ 
fig.legend([h_comp, h_acc], ["ECE", 'Accuracy'], loc="center", bbox_to_anchor=(0.5, 0.5), prop={"size":110}, labelspacing=2, ncol=2)

fig.savefig('./results/plots/legends/legend_delta_ECE.pdf', dpi=400, transparent=True, bbox_inches='tight')
